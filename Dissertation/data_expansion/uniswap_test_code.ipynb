# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import os
import time
import json
from datetime import datetime
from typing import List, Dict, Any, Optional

SNAPSHOT_URL = "https://hub.snapshot.org/graphql"

# ==========================
# ✅ Uniswap smoke test config
# ==========================
spaces = ["uniswapgovernance.eth"]

OUT_CSV = "TEST_uniswap_votes.csv"
PROGRESS_JSON = "TEST_uniswap_progress.json"

PROPOSAL_BATCH = 100
VOTES_PAGE_SIZE = 1000

SLEEP_BETWEEN_CALLS = 0.8   # 如果 429 多，就调到 1.2~1.5
MAX_RETRIES = 5
BACKOFF_BASE = 2.0

SMOKE_TEST_MAX_PROPOSALS = None  # ✅ 只跑前 3 个 proposal；通过后改成 None 或删掉限制
# ==========================


def post_gql(query: str, variables: Optional[Dict[str, Any]] = None) -> Dict[str, Any]:
    """GraphQL POST with retry + exponential backoff + better error visibility."""
    payload = {"query": query}
    if variables:
        payload["variables"] = variables

    last_err = None
    for attempt in range(MAX_RETRIES):
        try:
            r = requests.post(SNAPSHOT_URL, json=payload, timeout=30)

            # ✅ 关键：先把 400 的内容打印出来（只在失败时）
            if not r.ok:
                print("\n========== SNAPSHOT HTTP ERROR ==========")
                print("Status:", r.status_code)
                print("Response text (first 800 chars):", r.text[:800])
                print("Query (first 800 chars):", query[:800])
                print("========================================\n")

            # 对 429/5xx 才重试；400 属于 query 错误，一般不该重试
            if r.status_code in (429, 500, 502, 503, 504):
                raise RuntimeError(f"HTTP {r.status_code}: {r.text[:200]}")

            r.raise_for_status()
            data = r.json()

            if "errors" in data:
                # GraphQL errors：也打印出来便于定位
                print("\n========== SNAPSHOT GQL ERROR ==========")
                print(str(data["errors"])[:800])
                print("=======================================\n")
                raise RuntimeError(f"GQL errors: {str(data['errors'])[:200]}")

            return data["data"]

        except Exception as e:
            last_err = e

            # ✅ 400 这种一般是 query 逻辑错误：直接抛出，不要浪费重试
            if isinstance(e, requests.HTTPError) and r is not None and r.status_code == 400:
                raise RuntimeError(f"❌ 400 Bad Request（GraphQL query 不合法）: {r.text[:500]}")

            wait = (BACKOFF_BASE ** attempt) + 0.1 * attempt
            print(f"⚠️ 请求失败（attempt {attempt+1}/{MAX_RETRIES}）：{e} | backoff {wait:.1f}s")
            time.sleep(wait)

    raise RuntimeError(f"❌ 多次重试仍失败：{last_err}")



def load_progress() -> set:
    if os.path.exists(PROGRESS_JSON):
        with open(PROGRESS_JSON, "r", encoding="utf-8") as f:
            return set(json.load(f))
    return set()


def save_progress(completed: set):
    with open(PROGRESS_JSON, "w", encoding="utf-8") as f:
        json.dump(sorted(list(completed)), f, ensure_ascii=False, indent=2)


def fetch_all_proposals(space: str) -> List[Dict[str, Any]]:
    """Paginate proposals for a space."""
    all_props = []
    skip = 0

    print(f"\n🚀 开始抓取 Space={space} 的全部 proposals ...")
    while True:
        q = f"""
        {{
          proposals(first: {PROPOSAL_BATCH}, skip: {skip},
            where: {{ space_in: ["{space}"] }},
            orderBy: "created", orderDirection: desc
          ) {{
            id
            title
            body
            choices
            author
            state
            created
          }}
        }}
        """
        data = post_gql(q)
        batch = data.get("proposals", [])
        print(f"📦 {space} proposals: {skip + 1} ~ {skip + len(batch)}")

        if not batch:
            break

        all_props.extend(batch)
        if len(batch) < PROPOSAL_BATCH:
            break

        skip += PROPOSAL_BATCH
        time.sleep(SLEEP_BETWEEN_CALLS)

    print(f"✅ {space} proposals 总数：{len(all_props)}")
    return all_props


def fetch_all_votes_for_proposal(proposal_id: str) -> List[Dict[str, Any]]:
    """
    Cursor pagination via created_lt to bypass skip<=5000 limit.
    created is a 32-bit Int (Unix seconds), so created_lt must be <= 2,147,483,647.
    """
    all_votes = []
    created_lt = int(time.time()) + 10  # ✅ 合法范围内的“未来一点点”
    seen = set()

    while True:
        q = f"""
        {{
          votes(first: {VOTES_PAGE_SIZE},
            where: {{ proposal: "{proposal_id}", created_lt: {created_lt} }},
            orderBy: "created", orderDirection: desc
          ) {{
            voter
            choice
            vp
            created
          }}
        }}
        """
        data = post_gql(q)
        batch = data.get("votes", [])

        if not batch:
            break

        added = 0
        for v in batch:
            key = (v.get("voter"), v.get("created"))
            if key in seen:
                continue
            seen.add(key)
            all_votes.append(v)
            added += 1

        # ✅ 方便你观察是否分页在继续
        print(f"   ↳ fetched {added} votes | total={len(all_votes)} | next created_lt={batch[-1]['created']}")

        last_created = batch[-1]["created"]

        # 防止死循环（保险）
        if last_created >= created_lt:
            break

        created_lt = last_created

        if len(batch) < VOTES_PAGE_SIZE:
            break

        time.sleep(SLEEP_BETWEEN_CALLS)

    return all_votes



def compute_majority_choice(votes: List[Dict[str, Any]]) -> Optional[int]:
    """Return the most common choice index (int). Supports int or dict choice."""
    counter: Dict[int, int] = {}
    for v in votes:
        c = v.get("choice")
        if isinstance(c, int):
            counter[c] = counter.get(c, 0) + 1
        elif isinstance(c, dict):
            for k, val in c.items():
                try:
                    kk = int(k)
                except:
                    continue
                if val and val > 0:
                    counter[kk] = counter.get(kk, 0) + 1

    if not counter:
        return None
    return max(counter.items(), key=lambda x: x[1])[0]


def append_rows_to_csv(rows: List[Dict[str, Any]]):
    """Append rows to CSV incrementally."""
    if not rows:
        return
    df = pd.DataFrame(rows)
    header = not os.path.exists(OUT_CSV)
    df.to_csv(OUT_CSV, mode="a", index=False, header=header)


def main():
    completed = load_progress()
    print(f"📌 已完成 proposals 数：{len(completed)}（来自 {PROGRESS_JSON}）")

    for space in spaces:
        proposals = fetch_all_proposals(space)

        for i, p in enumerate(proposals, 1):
            if SMOKE_TEST_MAX_PROPOSALS is not None and i > SMOKE_TEST_MAX_PROPOSALS:
                print(f"\n🧪 Smoke test 到此结束：已测试前 {SMOKE_TEST_MAX_PROPOSALS} 个 proposals。")
                return

            pid = p["id"]
            if pid in completed:
                print(f"⏭️ 跳过已完成 proposal: {p.get('title','')[:60]}")
                continue

            print(f"\n🔍 [{space}] Proposal {i}/{len(proposals)}：{p.get('title','')[:80]}")

            # 1) 抓全量 votes（分页）
            votes = fetch_all_votes_for_proposal(pid)
            print(f"🧾 votes 数：{len(votes)}")

            if not votes:
                completed.add(pid)
                save_progress(completed)
                continue

            total_vp = sum(v.get("vp", 0) for v in votes)
            if total_vp == 0:
                completed.add(pid)
                save_progress(completed)
                continue

            majority = compute_majority_choice(votes)
            if majority is None:
                completed.add(pid)
                save_progress(completed)
                continue

            # 2) 生成记录（保留你原来的字段逻辑）
            rows = []
            for v in votes:
                vp = v.get("vp", 0)
                vp_ratio = vp / total_vp if total_vp else 0

                choice_used = None
                aligned = False

                c = v.get("choice")
                if isinstance(c, int):
                    choice_used = c
                    aligned = (c == majority)
                elif isinstance(c, dict):
                    choice_used = json.dumps(c, ensure_ascii=False)
                    aligned = (str(majority) in c and c[str(majority)] > 0)

                rows.append({
                    "Space": space,
                    "Proposal ID": pid,
                    "Proposal Title": p.get("title", ""),
                    "Proposal Body": (p.get("body") or "").replace("\n", " ").replace("\r", " ")[:1000],
                    "Created Time": datetime.utcfromtimestamp(p["created"]).isoformat(),
                    "Voter": v.get("voter"),
                    "Choice": choice_used,
                    "Voting Power": vp,
                    "VP Ratio (%)": round(vp_ratio * 100, 4),
                    "Is Whale": vp_ratio > 0.05,
                    "Aligned With Majority": aligned,
                    "Vote Timestamp": datetime.utcfromtimestamp(v["created"]).isoformat()
                })

            # 3) 增量写入 CSV + 更新进度
            append_rows_to_csv(rows)
            completed.add(pid)
            save_progress(completed)

            print(f"✅ 已写入 {len(rows)} 行 | 累计完成 proposals={len(completed)}")
            time.sleep(SLEEP_BETWEEN_CALLS)

    print(f"\n🎉 测试完成！输出文件：{OUT_CSV}")


if __name__ == "__main__":
    main()
# Out:
# 📌 已完成 proposals 数：102（来自 TEST_uniswap_progress.json）
#
# 🚀 开始抓取 Space=uniswapgovernance.eth 的全部 proposals ...
# 📦 uniswapgovernance.eth proposals: 1 ~ 100
# 📦 uniswapgovernance.eth proposals: 101 ~ 189
# ✅ uniswapgovernance.eth proposals 总数：189
# ⏭️ 跳过已完成 proposal: Strategic Renewal of Gnosis, Linea, and Mantle Deployments
# ⏭️ 跳过已完成 proposal: UNIfication
# ⏭️ 跳过已完成 proposal: Uniswap Community Proposal Factory
# ⏭️ 跳过已完成 proposal: Grow Uniswap on Plasma
# ⏭️ 跳过已完成 proposal:  Treasury Delegation Round 2 Elections
# ⏭️ 跳过已完成 proposal: GLI — Incentivized Delegation Vaults
# ⏭️ 跳过已完成 proposal: GLI — Treasury delegation Round 2
# ⏭️ 跳过已完成 proposal: Launching Uniswap v3 on Ronin with co-incentives
# ⏭️ 跳过已完成 proposal: Establish Uniswap Governance as “DUNI,” a Wyoming DUNA
# ⏭️ 跳过已完成 proposal: Uniswap Delegate Reward Initiative - Cycle 4
# ⏭️ 跳过已完成 proposal: [TEMP CHECK] - Etherlink Co-incentives Proposal
# ⏭️ 跳过已完成 proposal: Uniswap Unichain - USDS and sUSDS Co-Incentives Growth Manag
# ⏭️ 跳过已完成 proposal: Trial run a Technical Advisory Board (TAB)
# ⏭️ 跳过已完成 proposal: Uniswap Accountability Committee S4 Elections
# ⏭️ 跳过已完成 proposal: Four Chains for Analytics Hub for Uniswap’s Revitalization a
# ⏭️ 跳过已完成 proposal: [Temp Check] Analytics Hub for Uniswap’s Revitalization and
# ⏭️ 跳过已完成 proposal: [TEMP CHECK] Scaling V4 and Supporting Unichain
# ⏭️ 跳过已完成 proposal: [Temp Check/Revised] Treasury Delegation Round 2
# ⏭️ 跳过已完成 proposal: Approved Budgets Rebalancing (S4)
# ⏭️ 跳过已完成 proposal: UAC Renewal S4
# ⏭️ 跳过已完成 proposal: [TEMP CHECK] Establish Uniswap v4 Licensing Process
# ⏭️ 跳过已完成 proposal: [TEMP CHECK] BoB Uniswap v3 Incentives Package
# ⏭️ 跳过已完成 proposal: [Temp Check] Treasury Delegation Round 2
# ⏭️ 跳过已完成 proposal: [Temp Check] Saga Uniswap v3 Liquidity Incentives
# ⏭️ 跳过已完成 proposal: [Temp Check] Unichain and Uniswap v4 Liquidity Incentives
# ⏭️ 跳过已完成 proposal: [Temp Check] Uniswap Unleashed
# ⏭️ 跳过已完成 proposal: [Temp Check] Uniswap Delegate Reward Initiative - Cycle 3
# ⏭️ 跳过已完成 proposal: Incentive Package for Sonic (Formerly Fantom)
# ⏭️ 跳过已完成 proposal: Discretionary Budget from UAC for Co-Incentive Campaigns
# ⏭️ 跳过已完成 proposal: [TEMP CHECK] Metal L2: Bridging TradFi and DeFi Through Unis
# ⏭️ 跳过已完成 proposal: [TEMP CHECK] Scale Uniswap Liquidity on Celo
# ⏭️ 跳过已完成 proposal: [Temp Check] - Adopt The SEAL Safe Harbor Agreement
# ⏭️ 跳过已完成 proposal: [TEMP CHECK] Uniswap DAO Principles
# ⏭️ 跳过已完成 proposal: 🚀 Big News! Uniswap Just Voted to Supercharge the $gSTG Dist
# ⏭️ 跳过已完成 proposal: After Successful DAO Vote, Uniswap Moves Forward with Phase
# ⏭️ 跳过已完成 proposal: [TEMP CHECK] - Tally Uniswap Proposal
# ⏭️ 跳过已完成 proposal: Uniswap Growth Program Trial
# ⏭️ 跳过已完成 proposal: [TEMP CHECK] - Onboarding Package for Lisk
# ⏭️ 跳过已完成 proposal: Uniswap Accountability Committee S3 Elections
# ⏭️ 跳过已完成 proposal: Uniswap Delegate Race Tiebreaker
# ⏭️ 跳过已完成 proposal: Approved Budgets Rebalancing
# ⏭️ 跳过已完成 proposal: UAC Renewal S3
# ⏭️ 跳过已完成 proposal: [Temp Check] - Ethereum Foundation Attackathon Sponsorship
# ⏭️ 跳过已完成 proposal: [Temp Check] Uniswap Delegate Reward Initiative - Cycle 2
# ⏭️ 跳过已完成 proposal: [REDO: Temp Check] Activate 2, 3, 4 bps fee tiers on Uniswap
# ⏭️ 跳过已完成 proposal: [Temp Check] Activate 2, 3, 4 bps fee tiers on Uniswap v3 on
# ⏭️ 跳过已完成 proposal: [TEMP CHECK]- Revised - Uniswap Onboarding Package - OKX Cha
# ⏭️ 跳过已完成 proposal: [Temp Check] Forse Analytics for Uniswap Revitalization and
# ⏭️ 跳过已完成 proposal: [TEMP CHECK] Uniswap Onboarding Package - OKX Chain
# ⏭️ 跳过已完成 proposal: [Temp Check] Uniswap Onboarding Package - Gnosis Chain
# ⏭️ 跳过已完成 proposal: Uniswap Arbitrum LTIPP Matching
# ⏭️ 跳过已完成 proposal: [Temp Check] Onboard Uniswap to Redstone
# ⏭️ 跳过已完成 proposal: [Temp Check] Uniswap Delegate Reward -3 Months-Cycle 1
# ⏭️ 跳过已完成 proposal: DeFi Education Fund Temp Check- Options
# ⏭️ 跳过已完成 proposal: DeFi Education Fund Temp Check
# ⏭️ 跳过已完成 proposal: Uniswap Treasury Working Group (UTWG) Election
# ⏭️ 跳过已完成 proposal: [Temp Check] Uniswap Onboarding Package - Manta
# ⏭️ 跳过已完成 proposal: Update Uni v3/v2 Deployment Process (March 2024)
# ⏭️ 跳过已完成 proposal: [Temp Check] Onboard Uniswap to Sei
# ⏭️ 跳过已完成 proposal: [Temp Check] Mobilizing the Uniswap Treasury
# ⏭️ 跳过已完成 proposal: Uniswap V3 Fees: Factory Owner Amendment
# ⏭️ 跳过已完成 proposal: Activate Uniswap Protocol Governance
# ⏭️ 跳过已完成 proposal: [Temp Check] Deploy Uniswap v3 on Zora
# ⏭️ 跳过已完成 proposal: [Temp] Uni Onboarding Package - Mantle
# ⏭️ 跳过已完成 proposal: [Temp] Uni Onboarding Package - BSC
# ⏭️ 跳过已完成 proposal: [Temp] Uni Onboarding Package - Moonbeam
# ⏭️ 跳过已完成 proposal: [Temp] Uni Onboarding Package - Taiko
# ⏭️ 跳过已完成 proposal: [Temp] Uni Onboarding Package - Base
# ⏭️ 跳过已完成 proposal: [Temp] Uni Onboarding Package - Linea
# ⏭️ 跳过已完成 proposal: [Temp] Uni Onboarding Package - Blast
# ⏭️ 跳过已完成 proposal: [Temp] Uni Onboarding Package - zkSync
# ⏭️ 跳过已完成 proposal: [Temp] Uni Onboarding Package - Polygon zkEVM
# ⏭️ 跳过已完成 proposal: [Temp] Uni Onboarding Package - Scroll
# ⏭️ 跳过已完成 proposal: Uniswap Deployments Accountability Committee Competition
# ⏭️ 跳过已完成 proposal: [Temperature Check] Lower Onchain Proposal Threshold
# ⏭️ 跳过已完成 proposal: [Temperature Check] Deploy Uniswap v3 on Rootstock (Bitcoin
# ⏭️ 跳过已完成 proposal: Uniswap DAO Portal is Open, early registrants receive the 'E
# ⏭️ 跳过已完成 proposal: Uniswap DAO Portal is Open, early registrants receive the 'E
# ⏭️ 跳过已完成 proposal: Uniswap DAO Portal is Open, early registrants receive the 'E
# ⏭️ 跳过已完成 proposal: Uniswap DAO Portal is Open, early registrants receive the 'E
# ⏭️ 跳过已完成 proposal: After a Successful DAO Vote, Uniswap decided to Launch the P
# ⏭️ 跳过已完成 proposal: Uniswap DAO Portal is Open, all early registrants receive th
# ⏭️ 跳过已完成 proposal: [Temperature Check]: Competition of Delegation of UNI to Act
# ⏭️ 跳过已完成 proposal: [Temperature Check]: Delegation of UNI to Active but Underre
# ⏭️ 跳过已完成 proposal: [Temperature Check]: Invest in Ekubo Protocol
# ⏭️ 跳过已完成 proposal: Temperature Check - [Issue a Visa Card with Uniswap Logo ]
# ⏭️ 跳过已完成 proposal: UAGP Team Election
# ⏭️ 跳过已完成 proposal: UADP Team Election
# ⏭️ 跳过已完成 proposal: [Temp Check]: Complete initial funding of the UF
# ⏭️ 跳过已完成 proposal: [Temperature Check] Deploy Friendly Fork of Uniswap V3; ZERO
# ⏭️ 跳过已完成 proposal: [Temperature Check] - Deploy Uniswap V2 on all chains with V
# ⏭️ 跳过已完成 proposal: [Temperature Check] Deploy Uniswap V3 on Scroll
# ⏭️ 跳过已完成 proposal: [Temperature Check] Migrate the Celo Uniswap V3 Factory Cont
# ⏭️ 跳过已完成 proposal: ARB Distribution Proposal Poll
# ⏭️ 跳过已完成 proposal: [Temperature Check] Deploy Uniswap v3 on Fantom
# ⏭️ 跳过已完成 proposal: [Temperature Check] Deploy Uniswap v3 on Filecoin Virtual Ma
# ⏭️ 跳过已完成 proposal: [Temperature Check] Deploy Uniswap v3 on Base
# ⏭️ 跳过已完成 proposal: Deploy UniswapV3 on Linea
# ⏭️ 跳过已完成 proposal: Making Protocol Fees Operational: Asset to be held in the tr
# ⏭️ 跳过已完成 proposal: Making Protocol Fees Operational: Initial deployment chain
# ⏭️ 跳过已完成 proposal: Making Protocol Fees Operational: Fee options for V3
# ⏭️ 跳过已完成 proposal: [Temperature Check] Deploy Uniswap v3 on Moonbeam (2023)
#
# 🔍 [uniswapgovernance.eth] Proposal 103/189：[Temperature Check] Post-BSL cross-chain deployment process and creation of new
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1681268320
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1681180230
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1681089438
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1680969347
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1680937533
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1680906932
#    ↳ fetched 1000 votes | total=7000 | next created_lt=1680857137
#    ↳ fetched 931 votes | total=7931 | next created_lt=1680825173
# 🧾 votes 数：7931
# ✅ 已写入 7931 行 | 累计完成 proposals=103
#
# 🔍 [uniswapgovernance.eth] Proposal 104/189：Uniswap V3 Launch on zkEVM
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1680453030
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1680354173
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1680277194
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1680238701
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1680209468
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1680184494
#    ↳ fetched 1000 votes | total=7000 | next created_lt=1680164447
#    ↳ fetched 1000 votes | total=8000 | next created_lt=1680149931
#    ↳ fetched 1000 votes | total=9000 | next created_lt=1680139374
#    ↳ fetched 445 votes | total=9445 | next created_lt=1680110970
# 🧾 votes 数：9445
# ✅ 已写入 9445 行 | 累计完成 proposals=104
#
# 🔍 [uniswapgovernance.eth] Proposal 105/189：[Temperature Check] Deploy Uniswap V3 on Gnosis Chain
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1679978538
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1679900141
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1679836700
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1679779822
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1679746404
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1679720786
#    ↳ fetched 702 votes | total=6702 | next created_lt=1679689950
# 🧾 votes 数：6702
# ✅ 已写入 6702 行 | 累计完成 proposals=105
#
# 🔍 [uniswapgovernance.eth] Proposal 106/189：[Temperature Check] Deploy Uniswap v3 onto Kava EVM Network
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1678597021
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1678527240
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1678474158
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1678437456
#    ↳ fetched 934 votes | total=4934 | next created_lt=1678399341
# 🧾 votes 数：4934
# ✅ 已写入 4934 行 | 累计完成 proposals=106
#
# 🔍 [uniswapgovernance.eth] Proposal 107/189：[Temperature Check] Deploy Uniswap v3 on Avalanche
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1678183519
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1678106900
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1678031900
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1678005077
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1677953135
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1677899909
#    ↳ fetched 404 votes | total=6404 | next created_lt=1677888781
# 🧾 votes 数：6404
# ✅ 已写入 6404 行 | 累计完成 proposals=107
#
# 🔍 [uniswapgovernance.eth] Proposal 108/189：Temperature Check: Create Accoutability Committee
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1677570475
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1677497929
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1677419281
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1677374664
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1677327716
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1677309416
#    ↳ fetched 1000 votes | total=7000 | next created_lt=1677296836
#    ↳ fetched 1000 votes | total=8000 | next created_lt=1677267900
#    ↳ fetched 396 votes | total=8396 | next created_lt=1677249211
# 🧾 votes 数：8396
#
# 🔍 [uniswapgovernance.eth] Proposal 109/189：Consensus check- Uniswap DAO can help 80K UNI to Turkey to relief after the big
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1676984371
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1676888180
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1676810288
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1676739274
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1676712086
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1676689922
#    ↳ fetched 1000 votes | total=7000 | next created_lt=1676648158
#    ↳ fetched 259 votes | total=7259 | next created_lt=1676642519
# 🧾 votes 数：7259
# ✅ 已写入 7259 行 | 累计完成 proposals=109
#
# 🔍 [uniswapgovernance.eth] Proposal 110/189：Consensus Check - Uniswap helps t
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1676954408
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1676849226
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1676753805
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1676701988
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1676679028
#    ↳ fetched 723 votes | total=5723 | next created_lt=1676642426
# 🧾 votes 数：5723
# ✅ 已写入 5723 行 | 累计完成 proposals=110
#
# 🔍 [uniswapgovernance.eth] Proposal 111/189：Uniswap DAO can help 80K UNI to Turkey to relief after the big earthquake disast
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1676511364
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1676459719
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1676432043
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1676374475
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1676342909
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1676305690
#    ↳ fetched 800 votes | total=6800 | next created_lt=1676291432
# 🧾 votes 数：6800
# ✅ 已写入 6800 行 | 累计完成 proposals=111
#
# 🔍 [uniswapgovernance.eth] Proposal 112/189： [Temperature Check] Enable 1bp Fee Tier for UniswapV3 on Arbitrum
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1675698739
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1675653000
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1675585063
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1675511953
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1675482894
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1675443055
#    ↳ fetched 1000 votes | total=7000 | next created_lt=1675430363
#    ↳ fetched 1000 votes | total=8000 | next created_lt=1675419346
#    ↳ fetched 1000 votes | total=9000 | next created_lt=1675403306
#    ↳ fetched 687 votes | total=9687 | next created_lt=1675370666
# 🧾 votes 数：9687
# ✅ 已写入 9687 行 | 累计完成 proposals=112
#
# 🔍 [uniswapgovernance.eth] Proposal 113/189：[Temperature Check] Which bridge should Uniswap v3 use for cross-chain governanc
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1675064414
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1674997987
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1674958765
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1674909408
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1674891359
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1674878120
#    ↳ fetched 1000 votes | total=7000 | next created_lt=1674852343
#    ↳ fetched 1000 votes | total=8000 | next created_lt=1674827895
#    ↳ fetched 348 votes | total=8348 | next created_lt=1674817376
# 🧾 votes 数：8348
# ✅ 已写入 8348 行 | 累计完成 proposals=113
#
# 🔍 [uniswapgovernance.eth] Proposal 114/189：[Temperature Check] Should Uniswap v3 be deployed to BNB Chain? 🦄
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1674195189
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1674071867
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1674027808
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1673979150
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1673954042
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1673937256
#    ↳ fetched 495 votes | total=6495 | next created_lt=1673927529
# 🧾 votes 数：6495
# ✅ 已写入 6495 行 | 累计完成 proposals=114
#
# 🔍 [uniswapgovernance.eth] Proposal 115/189：Optimism-Uniswap LM Program: Update to LM Managers
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1673531752
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1673438524
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1673398519
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1673360238
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1673341643
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1673325765
#    ↳ fetched 96 votes | total=6096 | next created_lt=1673323889
# 🧾 votes 数：6096
# ✅ 已写入 6096 行 | 累计完成 proposals=115
#
# 🔍 [uniswapgovernance.eth] Proposal 116/189：Optimism-Uniswap LM Program: Update to Incentivized Pools
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1673515212
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1673425779
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1673371703
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1673352839
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1673334351
#    ↳ fetched 563 votes | total=5563 | next created_lt=1673323704
# 🧾 votes 数：5563
#
# 🔍 [uniswapgovernance.eth] Proposal 117/189：Community Governance Process Changes
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1671506334
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1671370529
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1671274548
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1671190901
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1671161148
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1671113744
#    ↳ fetched 1000 votes | total=7000 | next created_lt=1671095837
#    ↳ fetched 1000 votes | total=8000 | next created_lt=1671076141
#    ↳ fetched 603 votes | total=8603 | next created_lt=1671051621
# 🧾 votes 数：8603
# ✅ 已写入 8603 行 | 累计完成 proposals=117
#
# 🔍 [uniswapgovernance.eth] Proposal 118/189：[Temperature Check] Deploy Uniswap V3 on Scroll testnet
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1670073063
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1670045222
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1670007793
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1669988264
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1669975799
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1669966432
#    ↳ fetched 1000 votes | total=7000 | next created_lt=1669958716
#    ↳ fetched 1000 votes | total=8000 | next created_lt=1669949854
#    ↳ fetched 1000 votes | total=9000 | next created_lt=1669941672
#    ↳ fetched 1000 votes | total=10000 | next created_lt=1669915039
#    ↳ fetched 1000 votes | total=11000 | next created_lt=1669909451
#    ↳ fetched 1000 votes | total=12000 | next created_lt=1669907000
#    ↳ fetched 1000 votes | total=13000 | next created_lt=1669904664
#    ↳ fetched 1000 votes | total=14000 | next created_lt=1669903426
#    ↳ fetched 1000 votes | total=15000 | next created_lt=1669902071
#    ↳ fetched 212 votes | total=15212 | next created_lt=1669900806
# 🧾 votes 数：15212
# ✅ 已写入 15212 行 | 累计完成 proposals=118
#
# 🔍 [uniswapgovernance.eth] Proposal 119/189：[Consensus Check] Fix the Cross Chain Messaging Bridge on Arbitrum
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1669993166
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1669955754
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1669908186
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1669870719
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1669813640
#    ↳ fetched 1000 votes | total=6000 | next created_lt=1669789927
#    ↳ fetched 741 votes | total=6741 | next created_lt=1669763313
# 🧾 votes 数：6741
# ✅ 已写入 6741 行 | 累计完成 proposals=119
#
# 🔍 [uniswapgovernance.eth] Proposal 120/189：[Temperature Check] Fix the Cross Chain Messaging Bridge on Arbitrum
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1669498435
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1669350108
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1669277776
#    ↳ fetched 1000 votes | total=4000 | next created_lt=1669213444
#    ↳ fetched 1000 votes | total=5000 | next created_lt=1669176590
#    ↳ fetched 238 votes | total=5238 | next created_lt=1669161490
# 🧾 votes 数：5238
# ✅ 已写入 5238 行 | 累计完成 proposals=120
#
# 🔍 [uniswapgovernance.eth] Proposal 121/189：[Consensus Check] Deploy Uniswap V3 to Boba Network
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1669260411
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1669173883
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1669099120
#    ↳ fetched 514 votes | total=3514 | next created_lt=1669054880
# 🧾 votes 数：3514
# ✅ 已写入 3514 行 | 累计完成 proposals=121
#
# 🔍 [uniswapgovernance.eth] Proposal 122/189：[Temperature Check] Deploy Uniswap V3 to Boba Network
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1668586885
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1668523208
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1668486613
#    ↳ fetched 756 votes | total=3756 | next created_lt=1668446454
# 🧾 votes 数：3756
# ✅ 已写入 3756 行 | 累计完成 proposals=122
#
# 🔍 [uniswapgovernance.eth] Proposal 123/189：Optimism-Uniswap Protocol LM Program: Pool selection
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1665898888
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1665814756
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1665756300
#    ↳ fetched 25 votes | total=3025 | next created_lt=1665755289
# 🧾 votes 数：3025
# ✅ 已写入 3025 行 | 累计完成 proposals=123
#
# 🔍 [uniswapgovernance.eth] Proposal 124/189：Optimism-Uniswap Protocol LM Program: Structure
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1665896043
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1665814884
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1665757903
#    ↳ fetched 70 votes | total=3070 | next created_lt=1665755029
# 🧾 votes 数：3070
# ✅ 已写入 3070 行 | 累计完成 proposals=124
#
# 🔍 [uniswapgovernance.eth] Proposal 125/189：[Consensus Check] Deploy Uniswap V3 to zkSync
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1663859365
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1663743254
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1663668119
#    ↳ fetched 807 votes | total=3807 | next created_lt=1663612152
# 🧾 votes 数：3807
# ✅ 已写入 3807 行 | 累计完成 proposals=125
#
# 🔍 [uniswapgovernance.eth] Proposal 126/189：[Temperature Check] Deploy Uniswap V3 to zkSync
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1663173488
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1663115937
#    ↳ fetched 457 votes | total=2457 | next created_lt=1663080514
# 🧾 votes 数：2457
# ✅ 已写入 2457 行 | 累计完成 proposals=126
#
# 🔍 [uniswapgovernance.eth] Proposal 127/189：Should we deploy Uniswap v3 on Aurora?
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1663399626
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1663166361
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1662994946
#    ↳ fetched 45 votes | total=3045 | next created_lt=1662990333
# 🧾 votes 数：3045
# ✅ 已写入 3045 行 | 累计完成 proposals=127
#
# 🔍 [uniswapgovernance.eth] Proposal 128/189：[Consensus Check] Create the Uniswap Foundation
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1660231240
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1660179516
#    ↳ fetched 199 votes | total=2199 | next created_lt=1660146493
# 🧾 votes 数：2199
# ✅ 已写入 2199 行 | 累计完成 proposals=128
#
# 🔍 [uniswapgovernance.eth] Proposal 129/189：[Temperature Check] Create the Uniswap Foundation
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1660043943
#    ↳ fetched 860 votes | total=1860 | next created_lt=1659969504
# 🧾 votes 数：1860
# ✅ 已写入 1860 行 | 累计完成 proposals=129
#
# 🔍 [uniswapgovernance.eth] Proposal 130/189：[Consensus Check] "Fee switch" Pilot for Three Pairs
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1659765358
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1659669503
#    ↳ fetched 373 votes | total=2373 | next created_lt=1659650002
# 🧾 votes 数：2373
# ✅ 已写入 2373 行 | 累计完成 proposals=130
#
# 🔍 [uniswapgovernance.eth] Proposal 131/189：Temp Check: "Fee switch" activation for ETH/USDC & USDC/USDT
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1658240443
#    ↳ fetched 744 votes | total=1744 | next created_lt=1658191683
# 🧾 votes 数：1744
# ✅ 已写入 1744 行 | 累计完成 proposals=131
#
# 🔍 [uniswapgovernance.eth] Proposal 132/189：Should Uniswap provide Rage Trade with an additional use grant?
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1657705662
#    ↳ fetched 1000 votes | total=2000 | next created_lt=1657675556
#    ↳ fetched 1000 votes | total=3000 | next created_lt=1657641862
#    ↳ fetched 144 votes | total=3144 | next created_lt=1657636605
# 🧾 votes 数：3144
# ✅ 已写入 3144 行 | 累计完成 proposals=132
#
# 🔍 [uniswapgovernance.eth] Proposal 133/189：[Consensus Check] - Enable 1bp Fee Tier on UniswapV3 Optimism(L2)
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1656261051
#    ↳ fetched 315 votes | total=1315 | next created_lt=1656214077
# 🧾 votes 数：1315
# ✅ 已写入 1315 行 | 累计完成 proposals=133
#
# 🔍 [uniswapgovernance.eth] Proposal 134/189：[Temperature Check] Should the Uniswap community participate in the Protocol Gui
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1654221237
#    ↳ fetched 139 votes | total=1139 | next created_lt=1654183814
# 🧾 votes 数：1139
# ✅ 已写入 1139 行 | 累计完成 proposals=134
#
# 🔍 [uniswapgovernance.eth] Proposal 135/189：[Consensus Check] Should Uniswap v3 be deployed to Gnosis Chain?
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1649937495
#    ↳ fetched 697 votes | total=1697 | next created_lt=1649869503
# 🧾 votes 数：1697
# ✅ 已写入 1697 行 | 累计完成 proposals=135
#
# 🔍 [uniswapgovernance.eth] Proposal 136/189：[Consensus Check] Deploy Uniswap V3 on Moonbeam
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1649160031
#    ↳ fetched 477 votes | total=1477 | next created_lt=1649118418
# 🧾 votes 数：1477
# ✅ 已写入 1477 行 | 累计完成 proposals=136
#
# 🔍 [uniswapgovernance.eth] Proposal 137/189：[Temperature Check] Deploy Uniswap V3 on Moonbeam
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1648703465
#    ↳ fetched 301 votes | total=1301 | next created_lt=1648682637
# 🧾 votes 数：1301
# ✅ 已写入 1301 行 | 累计完成 proposals=137
#
# 🔍 [uniswapgovernance.eth] Proposal 138/189：Temperature Check - Should Uniswap v3 be deployed to Gnosis Chain?
#    ↳ fetched 909 votes | total=909 | next created_lt=1647955141
# 🧾 votes 数：909
# ✅ 已写入 909 行 | 累计完成 proposals=138
#
# 🔍 [uniswapgovernance.eth] Proposal 139/189：Consensus Check - Should Uniswap add the 1bp fee tier to Polygon?
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1647923852
#    ↳ fetched 338 votes | total=1338 | next created_lt=1647903644
# 🧾 votes 数：1338
# ✅ 已写入 1338 行 | 累计完成 proposals=139
#
# 🔍 [uniswapgovernance.eth] Proposal 140/189：Temp Check - Should Uniswap add the 1bp fee tier to Polygon?
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1647654239
#    ↳ fetched 31 votes | total=1031 | next created_lt=1647643343
# 🧾 votes 数：1031
# ✅ 已写入 1031 行 | 累计完成 proposals=140
#
# 🔍 [uniswapgovernance.eth] Proposal 141/189：[Consensus Check] Should we deploy Uniswap V3 on Celo?
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1647316121
#    ↳ fetched 391 votes | total=1391 | next created_lt=1647304301
# 🧾 votes 数：1391
# ✅ 已写入 1391 行 | 累计完成 proposals=141
#
# 🔍 [uniswapgovernance.eth] Proposal 142/189：Should we deploy Uniswap V3 on Celo?
#    ↳ fetched 914 votes | total=914 | next created_lt=1646928048
# 🧾 votes 数：914
# ✅ 已写入 914 行 | 累计完成 proposals=142
#
# 🔍 [uniswapgovernance.eth] Proposal 143/189：Consensus Check - Should Uniswap governance contribute funding to the Nomic Foun
#    ↳ fetched 1000 votes | total=1000 | next created_lt=1646702380
#    ↳ fetched 414 votes | total=1414 | next created_lt=1646658122
# 🧾 votes 数：1414
# ✅ 已写入 1414 行 | 累计完成 proposals=143
#
# 🔍 [uniswapgovernance.eth] Proposal 144/189：Should Uniswap governance contribute funding to the Nomic Foundation?
#    ↳ fetched 851 votes | total=851 | next created_lt=1646222379
# 🧾 votes 数：851
# ✅ 已写入 851 行 | 累计完成 proposals=144
#
# 🔍 [uniswapgovernance.eth] Proposal 145/189：Funding the Fee Switch Activation
#    ↳ fetched 335 votes | total=335 | next created_lt=1644775373
# 🧾 votes 数：335
# ✅ 已写入 335 行 | 累计完成 proposals=145
#
# 🔍 [uniswapgovernance.eth] Proposal 146/189：How should Uniswap community support "Adopt unicorn on unicode" proposal
#    ↳ fetched 177 votes | total=177 | next created_lt=1644498428
# 🧾 votes 数：177
#
# 🔍 [uniswapgovernance.eth] Proposal 147/189：Temperature Check - Deploy Uniswap V3 on Harmony through an Additional Use Grant
#    ↳ fetched 275 votes | total=275 | next created_lt=1644421268
# 🧾 votes 数：275
# ✅ 已写入 275 行 | 累计完成 proposals=147
#
# 🔍 [uniswapgovernance.eth] Proposal 148/189：Consensus Check -  Should Uniswap Provide Voltz with v3 Additional Use Grant
#    ↳ fetched 362 votes | total=362 | next created_lt=1644224853
# 🧾 votes 数：362
# ✅ 已写入 362 行 | 累计完成 proposals=148
#
# 🔍 [uniswapgovernance.eth] Proposal 149/189：Temperature Check - Should Uniswap Provide Voltz with v3 Additional Use Grant?
#    ↳ fetched 354 votes | total=354 | next created_lt=1642582871
# 🧾 votes 数：354
# ✅ 已写入 354 行 | 累计完成 proposals=149
#
# 🔍 [uniswapgovernance.eth] Proposal 150/189：Temperature Check—Support izumi Finance as Uniswap V3 official partner of Liquid
#    ↳ fetched 253 votes | total=253 | next created_lt=1639546094
# 🧾 votes 数：253
# ✅ 已写入 253 行 | 累计完成 proposals=150
#
# 🔍 [uniswapgovernance.eth] Proposal 151/189：Consensus check - Should Uniswap incentivize liquidity on Optimism and Arbitrum?
#    ↳ fetched 275 votes | total=275 | next created_lt=1638285026
# 🧾 votes 数：275
# ✅ 已写入 275 行 | 累计完成 proposals=151
#
# 🔍 [uniswapgovernance.eth] Proposal 152/189：Consensus Check - Should Uniswap v3 be deployed to Polygon?
#    ↳ fetched 379 votes | total=379 | next created_lt=1638148443
# 🧾 votes 数：379
# ✅ 已写入 379 行 | 累计完成 proposals=152
#
# 🔍 [uniswapgovernance.eth] Proposal 153/189：Is uniswap supported to accelerate layer2?
#    ↳ fetched 467 votes | total=467 | next created_lt=1637972233
# 🧾 votes 数：467
# ✅ 已写入 467 行 | 累计完成 proposals=153
#
# 🔍 [uniswapgovernance.eth] Proposal 154/189：Should Uniswap v3 be deployed to Polygon?
#    ↳ fetched 300 votes | total=300 | next created_lt=1637612726
# 🧾 votes 数：300
# ✅ 已写入 300 行 | 累计完成 proposals=154
#
# 🔍 [uniswapgovernance.eth] Proposal 155/189：Temperature Check - Should Uniswap incentivize liquidity on Arbitrum and Optimis
#    ↳ fetched 300 votes | total=300 | next created_lt=1637053570
# 🧾 votes 数：300
# ✅ 已写入 300 行 | 累计完成 proposals=155
#
# 🔍 [uniswapgovernance.eth] Proposal 156/189：Temperature Check - Should Uniswap incentivize Liquidity on Optimism and Arbitru
#    ↳ fetched 232 votes | total=232 | next created_lt=1636391058
# 🧾 votes 数：232
# ✅ 已写入 232 行 | 累计完成 proposals=156
#
# 🔍 [uniswapgovernance.eth] Proposal 157/189：Consensus Check - Add 1 Basis Point Fee Tier
#    ↳ fetched 389 votes | total=389 | next created_lt=1635123286
# 🧾 votes 数：389
# ✅ 已写入 389 行 | 累计完成 proposals=157
#
# 🔍 [uniswapgovernance.eth] Proposal 158/189：Should the DEF move its assets to a custodial wallet viewable on chain?
#    ↳ fetched 252 votes | total=252 | next created_lt=1634566729
# 🧾 votes 数：252
# ✅ 已写入 252 行 | 累计完成 proposals=158
#
# 🔍 [uniswapgovernance.eth] Proposal 159/189：Should we deploy Uniswap V3 on AVAX?
#    ↳ fetched 228 votes | total=228 | next created_lt=1631916192
# 🧾 votes 数：228
# ✅ 已写入 228 行 | 累计完成 proposals=159
#
# 🔍 [uniswapgovernance.eth] Proposal 160/189：Temperature Check: Support $oneUNI Stablecoin
#    ↳ fetched 285 votes | total=285 | next created_lt=1630019280
# 🧾 votes 数：285
# ✅ 已写入 285 行 | 累计完成 proposals=160
#
# 🔍 [uniswapgovernance.eth] Proposal 161/189：Consensus Check: Upgrade Governance Contract to Governor Bravo
#    ↳ fetched 605 votes | total=605 | next created_lt=1628517982
# 🧾 votes 数：605
# ✅ 已写入 605 行 | 累计完成 proposals=161
#
# 🔍 [uniswapgovernance.eth] Proposal 162/189：Begin Uniswap Liquidity Program v0.1
#    ↳ fetched 276 votes | total=276 | next created_lt=1627554604
# 🧾 votes 数：276
# ✅ 已写入 276 行 | 累计完成 proposals=162
#
# 🔍 [uniswapgovernance.eth] Proposal 163/189：Temperature Check: Upgrade Governance Contract to Governor Bravo
#    ↳ fetched 296 votes | total=296 | next created_lt=1627358790
# 🧾 votes 数：296
# ✅ 已写入 296 行 | 累计完成 proposals=163
#
# 🔍 [uniswapgovernance.eth] Proposal 164/189：Consensus Check - Create Uniswap Volume KPI Options to help divest Uniswap’s Com
#    ↳ fetched 181 votes | total=181 | next created_lt=1627316710
# 🧾 votes 数：181
# ✅ 已写入 181 行 | 累计完成 proposals=164
#
# 🔍 [uniswapgovernance.eth] Proposal 165/189：Turning on the fee switch for V2
#    ↳ fetched 354 votes | total=354 | next created_lt=1626724850
# 🧾 votes 数：354
# ✅ 已写入 354 行 | 累计完成 proposals=165
#
# 🔍 [uniswapgovernance.eth] Proposal 166/189：Temperature Check - [Merge the Uniswap Grant Program into Uniswap DAO Governance
#    ↳ fetched 136 votes | total=136 | next created_lt=1626568145
# 🧾 votes 数：136
# ✅ 已写入 136 行 | 累计完成 proposals=166
#
# 🔍 [uniswapgovernance.eth] Proposal 167/189：Consensus Check - ABOLISH Delegates and change the UNI Governance Voting System
#    ↳ fetched 471 votes | total=471 | next created_lt=1626366673
# 🧾 votes 数：471
# ✅ 已写入 471 行 | 累计完成 proposals=167
#
# 🔍 [uniswapgovernance.eth] Proposal 168/189：[Proposal] Removal of established cranial follicles fund.
#    ↳ fetched 523 votes | total=523 | next created_lt=1626307285
# 🧾 votes 数：523
# ✅ 已写入 523 行 | 累计完成 proposals=168
#
# 🔍 [uniswapgovernance.eth] Proposal 169/189：Should UGP be reinstated with existing funds?
#    ↳ fetched 533 votes | total=533 | next created_lt=1626213918
# 🧾 votes 数：533
# ✅ 已写入 533 行 | 累计完成 proposals=169
#
# 🔍 [uniswapgovernance.eth] Proposal 170/189：Create a CAPITAL PROTECTION Tool for v3!!
#    ↳ fetched 350 votes | total=350 | next created_lt=1625932447
# 🧾 votes 数：350
# ✅ 已写入 350 行 | 累计完成 proposals=170
#
# 🔍 [uniswapgovernance.eth] Proposal 171/189：Temperature Check - Allocate 1.5M UNI to Go-Ethereum long-term Talent-Acquisitio
#    ↳ fetched 510 votes | total=510 | next created_lt=1625937279
# 🧾 votes 数：510
# ✅ 已写入 510 行 | 累计完成 proposals=171
#
# 🔍 [uniswapgovernance.eth] Proposal 172/189：Consensus Check: Raise the proposal quorum threshold
#    ↳ fetched 297 votes | total=297 | next created_lt=1625623635
# 🧾 votes 数：297
# ✅ 已写入 297 行 | 累计完成 proposals=172
# 🔍 [uniswapgovernance.eth] Proposal 173/189：Consensus Check: Community-Enabled Analytics via Yield-Generating Investment Str
#    ↳ fetched 330 votes | total=330 | next created_lt=1625440941
# 🧾 votes 数：330
# ✅ 已写入 330 行 | 累计完成 proposals=173
#
# 🔍 [uniswapgovernance.eth] Proposal 174/189：Temp Check: Larger Grant Construct // CEA + No Negative Net UNI
#    ↳ fetched 464 votes | total=464 | next created_lt=1624388029
# 🧾 votes 数：464
# ✅ 已写入 464 行 | 累计完成 proposals=174
#
# 🔍 [uniswapgovernance.eth] Proposal 175/189：Temperature Check: Raise the proposal quorum threshold
#    ↳ fetched 369 votes | total=369 | next created_lt=1624049742
# 🧾 votes 数：369
# ✅ 已写入 369 行 | 累计完成 proposals=175
#
# 🔍 [uniswapgovernance.eth] Proposal 176/189：Temperature Check - Managing Systemic Risk in Uniswap’s Community Treasury using
#    ↳ fetched 408 votes | total=408 | next created_lt=1623693897
# 🧾 votes 数：408
# ✅ 已写入 408 行 | 累计完成 proposals=176
#
# 🔍 [uniswapgovernance.eth] Proposal 177/189：Consensus Check — Funding a Political Defense of DeFi
#    ↳ fetched 413 votes | total=413 | next created_lt=1622504531
# 🧾 votes 数：413
# ✅ 已写入 413 行 | 累计完成 proposals=177
#
# 🔍 [uniswapgovernance.eth] Proposal 178/189：Donate $50M worth of UNI to Chris Blec to leave DeFi for good
#    ↳ fetched 516 votes | total=516 | next created_lt=1622340052
# 🧾 votes 数：516
# ✅ 已写入 516 行 | 累计完成 proposals=178
#
# 🔍 [uniswapgovernance.eth] Proposal 179/189：Managing Systemic Risk in Uniswap's Community Treasury using KPI Options
#    ↳ fetched 201 votes | total=201 | next created_lt=1622577400
# 🧾 votes 数：201
# ✅ 已写入 201 行 | 累计完成 proposals=179
#
# 🔍 [uniswapgovernance.eth] Proposal 180/189：Should Uniswap lower the proposal submission threshold?
#    ↳ fetched 360 votes | total=360 | next created_lt=1622218856
# 🧾 votes 数：360
# ✅ 已写入 360 行 | 累计完成 proposals=180
#
# 🔍 [uniswapgovernance.eth] Proposal 181/189：Funding a Political Defense of DeFi
#    ↳ fetched 462 votes | total=462 | next created_lt=1622143533
# 🧾 votes 数：462
# ✅ 已写入 462 行 | 累计完成 proposals=181
#
# 🔍 [uniswapgovernance.eth] Proposal 182/189：Deploy Uniswap v3 on Arbitrum
#    ↳ fetched 871 votes | total=871 | next created_lt=1622045537
# 🧾 votes 数：871
# ✅ 已写入 871 行 | 累计完成 proposals=182
#
# 🔍 [uniswapgovernance.eth] Proposal 183/189：Can UGP increase their Q2 budget to $1.5M?
#    ↳ fetched 570 votes | total=570 | next created_lt=1616776701
# 🧾 votes 数：570
# ✅ 已写入 570 行 | 累计完成 proposals=183
#
# 🔍 [uniswapgovernance.eth] Proposal 184/189：[Temp Check] Fund UNI Grants Program?
# 🧾 votes 数：0
#
# 🔍 [uniswapgovernance.eth] Proposal 185/189：[Consensus Check] Should Uniswap Distribute UNI to Liquidity Providers?
#    ↳ fetched 89 votes | total=89 | next created_lt=1606162159
# 🧾 votes 数：89
# ✅ 已写入 89 行 | 累计完成 proposals=185
#
# 🔍 [uniswapgovernance.eth] Proposal 186/189：[Temp Check] Should Uniswap Distribute UNI to Liquidity Providers?
#    ↳ fetched 286 votes | total=286 | next created_lt=1605556851
# 🧾 votes 数：286
# ✅ 已写入 286 行 | 累计完成 proposals=186
#
# 🔍 [uniswapgovernance.eth] Proposal 187/189：Liquidity mining continuation budget
#    ↳ fetched 15 votes | total=15 | next created_lt=1605348557
# 🧾 votes 数：15
# ✅ 已写入 15 行 | 累计完成 proposals=187
#
# 🔍 [uniswapgovernance.eth] Proposal 188/189：Uniswap Temperature check - [Should we increase the votingDelay?]
#    ↳ fetched 6 votes | total=6 | next created_lt=1604062337
# 🧾 votes 数：6
# ✅ 已写入 6 行 | 累计完成 proposals=188
#
# 🔍 [uniswapgovernance.eth] Proposal 189/189：Retroactive Airdrop For Proxy Contract Users (e.g. 1Inch, Dharma, Matcha, etc.)
#    ↳ fetched 40 votes | total=40 | next created_lt=1600767057
# 🧾 votes 数：40
# ✅ 已写入 40 行 | 累计完成 proposals=189
#
# 🎉 测试完成！输出文件：TEST_uniswap_votes.csv
