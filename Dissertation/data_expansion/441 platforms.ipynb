# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (2.31.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import os, json

print("CWD:", os.getcwd())
print("SPACES_FILE exists?", os.path.exists(SPACES_FILE))
if os.path.exists(SPACES_FILE):
    print("File size:", os.path.getsize(SPACES_FILE), "bytes")
    with open(SPACES_FILE, "r", encoding="utf-8") as f:
        raw = f.read(500)
    print("First 500 chars:\n", raw)

    obj = json.loads(raw + "}") if False else None
# Out:
# CWD: C:\Users\DELL\Untitled Folder 1
# SPACES_FILE exists? True
# File size: 10439 bytes
# First 500 chars:
#  {
#   "mode": "follower_only_knee_fixed_rank",
#   "knee_rank_1based": 441,
#   "boundary_space_id": "zombiezdao.eth",
#   "boundary_proposalsCount": 45,
#   "boundary_followersCount": 325,
#   "coverage_over_total_followers_in_universe": 0.9598724319006992,
#   "total_followers_in_universe": 4334626.0,
#   "min_proposals_filter": 10,
#   "selected_count": 441,
#   "selected_space_ids": [
#     "stgdao.eth",
#     "arbitrumfoundation.eth",
#     "opcollective.eth",
#     "aavedao.eth",
#     "gitcoindao.eth",
#     "ens.eth",

# %%
import requests
import pandas as pd
import os
import time
import json
from datetime import datetime
from typing import List, Dict, Any, Optional, Tuple

SNAPSHOT_URL = "https://hub.snapshot.org/graphql"

# ==========================
# ✅ CONFIG
# ==========================
SPACES_FILE = "data/processed/selected_spaces_follower_knee.json"

OUT_DIR = "data/processed/votes_441"
PROGRESS_DIR = os.path.join(OUT_DIR, "progress_by_space")
os.makedirs(OUT_DIR, exist_ok=True)
os.makedirs(PROGRESS_DIR, exist_ok=True)

OUT_CSV = os.path.join(OUT_DIR, "snapshot_votes_441_spaces.csv")
FAIL_LOG = os.path.join(OUT_DIR, "failures.log")

PROPOSAL_BATCH = 100
VOTES_PAGE_SIZE = 1000

SLEEP_BETWEEN_CALLS = 1.5   # 429 多就调到 1.3~1.8
MAX_RETRIES = 6
BACKOFF_BASE = 2.0

# 小规模测试开关：先跑 5 个 space、每个 3 个 proposal
MAX_SPACES = None
MAX_PROPOSALS_PER_SPACE = None

# 是否先拉 followersCount 并按重要性排序（推荐开启）
SORT_BY_FOLLOWERS = True
# ==========================


# ---------- Robust GraphQL ----------
def post_gql(query: str, variables: Optional[Dict[str, Any]] = None) -> Dict[str, Any]:
    """
    GraphQL POST with:
    - retry + exponential backoff for 429/5xx/timeouts
    - detailed error printing for debugging
    - stop-fast on 400 (query invalid)
    """
    payload = {"query": query}
    if variables:
        payload["variables"] = variables

    last_err = None
    last_status = None
    last_text = None

    for attempt in range(MAX_RETRIES):
        try:
            r = requests.post(SNAPSHOT_URL, json=payload, timeout=30)
            last_status = r.status_code
            last_text = r.text

            # 400: query 不合法，直接抛出（不浪费重试）
            if r.status_code == 400:
                raise RuntimeError(f"HTTP 400 Bad Request: {r.text[:800]}")

            # 429/5xx: 需要重试
            if r.status_code in (429, 500, 502, 503, 504):
                raise RuntimeError(f"HTTP {r.status_code}: {r.text[:200]}")

            r.raise_for_status()

            data = r.json()
            if "errors" in data:
                # GraphQL errors 有时是 rate limit/后端抖动，也允许重试
                raise RuntimeError(f"GQL errors: {str(data['errors'])[:800]}")

            return data["data"]

        except Exception as e:
            last_err = e
            # 400 不重试（通常无意义）
            if isinstance(e, RuntimeError) and "HTTP 400" in str(e):
                print("\n========== SNAPSHOT 400 BAD REQUEST ==========")
                print("Response (first 800 chars):", last_text[:800] if last_text else "")
                print("Query (first 800 chars):", query[:800])
                print("=============================================\n")
                raise

            wait = (BACKOFF_BASE ** attempt) + 0.2 * attempt
            print(f"⚠️ 请求失败（attempt {attempt+1}/{MAX_RETRIES}）：{e} | backoff {wait:.1f}s")
            time.sleep(wait)

    raise RuntimeError(
        f"❌ GraphQL failed after {MAX_RETRIES} retries. "
        f"last_status={last_status}, last_error={repr(last_err)}"
    )


# ---------- Load 441 spaces from your JSON ----------
def load_selected_space_ids(spaces_file: str) -> List[str]:
    """
    Your file structure:
    {
      ...
      "selected_space_ids": ["stgdao.eth", "arbitrumfoundation.eth", ...]
    }
    """
    with open(spaces_file, "r", encoding="utf-8") as f:
        obj = json.load(f)

    ids = obj.get("selected_space_ids", [])
    if not isinstance(ids, list):
        raise ValueError("selected_space_ids is not a list in SPACES_FILE")

    # dedup while preserving order
    seen = set()
    out = []
    for s in ids:
        if isinstance(s, str) and s and s not in seen:
            seen.add(s)
            out.append(s)

    return out


# ---------- Progress per space ----------
def progress_path_for_space(space: str) -> str:
    safe = space.replace("/", "_").replace(":", "_")
    return os.path.join(PROGRESS_DIR, f"progress_{safe}.json")


def load_progress(space: str) -> set:
    path = progress_path_for_space(space)
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            return set(json.load(f))
    return set()


def save_progress(space: str, completed: set):
    path = progress_path_for_space(space)
    with open(path, "w", encoding="utf-8") as f:
        json.dump(sorted(list(completed)), f, ensure_ascii=False, indent=2)


# ---------- Snapshot helpers ----------
def fetch_space_followers(space: str) -> Optional[int]:
    q = f"""
    {{
      space(id: "{space}") {{
        followersCount
      }}
    }}
    """
    data = post_gql(q)
    sp = data.get("space")
    if not sp:
        return None
    fc = sp.get("followersCount")
    try:
        return int(fc) if fc is not None else None
    except:
        return None


def fetch_all_proposals(space: str) -> List[Dict[str, Any]]:
    all_props = []
    skip = 0

    print(f"\n🚀 开始抓取 Space={space} 的全部 proposals ...")
    while True:
        q = f"""
        {{
          proposals(first: {PROPOSAL_BATCH}, skip: {skip},
            where: {{ space_in: ["{space}"] }},
            orderBy: "created", orderDirection: desc
          ) {{
            id
            title
            body
            choices
            author
            state
            created
          }}
        }}
        """
        data = post_gql(q)
        batch = data.get("proposals", [])
        print(f"📦 {space} proposals: {skip + 1} ~ {skip + len(batch)}")

        if not batch:
            break

        all_props.extend(batch)
        if len(batch) < PROPOSAL_BATCH:
            break

        skip += PROPOSAL_BATCH
        time.sleep(SLEEP_BETWEEN_CALLS)

    print(f"✅ {space} proposals 总数：{len(all_props)}")
    return all_props


def fetch_all_votes_for_proposal(proposal_id: str) -> List[Dict[str, Any]]:
    """
    Cursor pagination via created_lt (desc order) to bypass skip<=5000 limit.
    IMPORTANT: created is GraphQL Int (32-bit signed), so created_lt must be <= 2,147,483,647.
    """
    all_votes = []
    created_lt = int(time.time()) + 10  # ✅ safe 32-bit range
    seen = set()

    while True:
        q = f"""
        {{
          votes(first: {VOTES_PAGE_SIZE},
            where: {{ proposal: "{proposal_id}", created_lt: {created_lt} }},
            orderBy: "created", orderDirection: desc
          ) {{
            voter
            choice
            vp
            created
          }}
        }}
        """
        data = post_gql(q)
        batch = data.get("votes", [])

        if not batch:
            break

        for v in batch:
            key = (v.get("voter"), v.get("created"))
            if key in seen:
                continue
            seen.add(key)
            all_votes.append(v)

        last_created = batch[-1]["created"]
        if last_created >= created_lt:  # safety against infinite loop
            break

        created_lt = last_created

        if len(batch) < VOTES_PAGE_SIZE:
            break

        time.sleep(SLEEP_BETWEEN_CALLS)

    return all_votes


def compute_majority_choice(votes: List[Dict[str, Any]]) -> Optional[int]:
    counter: Dict[int, int] = {}
    for v in votes:
        c = v.get("choice")
        if isinstance(c, int):
            counter[c] = counter.get(c, 0) + 1
        elif isinstance(c, dict):
            for k, val in c.items():
                try:
                    kk = int(k)
                except:
                    continue
                if val and val > 0:
                    counter[kk] = counter.get(kk, 0) + 1

    if not counter:
        return None
    return max(counter.items(), key=lambda x: x[1])[0]


def append_rows_to_csv(rows: List[Dict[str, Any]]):
    if not rows:
        return
    df = pd.DataFrame(rows)
    header = not os.path.exists(OUT_CSV)
    df.to_csv(OUT_CSV, mode="a", index=False, header=header)


def log_failure(tag: str, msg: str):
    with open(FAIL_LOG, "a", encoding="utf-8") as f:
        f.write(f"[{tag}] {msg}\n")


# ---------- MAIN ----------
def main():
    spaces = load_selected_space_ids(SPACES_FILE)
    print(f"✅ 从 selected_space_ids 读取 spaces 数量：{len(spaces)}")

    if MAX_SPACES is not None:
        spaces = spaces[:MAX_SPACES]
        print(f"🧪 MAX_SPACES={MAX_SPACES} → 本次只跑前 {len(spaces)} 个 spaces")

    # Optional: fetch followersCount and sort
    space_items: List[Tuple[str, Optional[int]]] = [(s, None) for s in spaces]

    if SORT_BY_FOLLOWERS:
        print("🔎 正在获取 followersCount 并按重要性排序（None 放最后）...")
        tmp = []
        for i, s in enumerate(spaces, 1):
            try:
                fc = fetch_space_followers(s)
            except Exception as e:
                fc = None
                log_failure("FOLLOWERS_FAIL", f"{s} | {repr(e)}")
            tmp.append((s, fc))
            if i % 25 == 0:
                print(f"   ... followersCount fetched {i}/{len(spaces)}")
            time.sleep(0.2)

        tmp.sort(key=lambda x: (x[1] is None, -(x[1] or 0)))
        space_items = tmp
        print("✅ followers 排序后前 5 个：", space_items[:5])

    # Start crawling
    for idx, (space, followers) in enumerate(space_items, 1):
        print("\n" + "=" * 90)
        print(f"🏷️  Space [{idx}/{len(space_items)}]: {space} | followersCount={followers}")
        print("=" * 90)

        completed = load_progress(space)
        print(f"📌 已完成 proposals 数：{len(completed)}（{progress_path_for_space(space)}）")

        # Space-level try
        try:
            proposals = fetch_all_proposals(space)
        except Exception as e:
            log_failure("SPACE_FAIL", f"{space} | {repr(e)}")
            print(f"❌ Space 抓 proposals 失败（已记录 failures.log），跳过：{e}")
            continue

        if MAX_PROPOSALS_PER_SPACE is not None:
            proposals = proposals[:MAX_PROPOSALS_PER_SPACE]
            print(f"🧪 MAX_PROPOSALS_PER_SPACE={MAX_PROPOSALS_PER_SPACE} → 本次只跑 {len(proposals)} 个 proposals")

        for i, p in enumerate(proposals, 1):
            pid = p["id"]
            if pid in completed:
                continue

            title = (p.get("title") or "")[:80]
            print(f"\n🔍 [{space}] Proposal {i}/{len(proposals)}：{title}")

            try:
                votes = fetch_all_votes_for_proposal(pid)
                print(f"🧾 votes 数：{len(votes)}")

                if not votes:
                    completed.add(pid)
                    save_progress(space, completed)
                    continue

                total_vp = sum(v.get("vp", 0) for v in votes)
                if total_vp == 0:
                    completed.add(pid)
                    save_progress(space, completed)
                    continue

                majority = compute_majority_choice(votes)
                if majority is None:
                    completed.add(pid)
                    save_progress(space, completed)
                    continue

                rows = []
                for v in votes:
                    vp = v.get("vp", 0)
                    vp_ratio = vp / total_vp if total_vp else 0

                    choice_used = None
                    aligned = False
                    c = v.get("choice")

                    if isinstance(c, int):
                        choice_used = c
                        aligned = (c == majority)
                    elif isinstance(c, dict):
                        choice_used = json.dumps(c, ensure_ascii=False)
                        aligned = (str(majority) in c and c[str(majority)] > 0)

                    rows.append({
                        "Space": space,
                        "FollowersCount": followers,
                        "Proposal ID": pid,
                        "Proposal Title": p.get("title", ""),
                        "Proposal Body": (p.get("body") or "").replace("\n", " ").replace("\r", " ")[:1000],
                        "Created Time": datetime.utcfromtimestamp(p["created"]).isoformat(),
                        "Voter": v.get("voter"),
                        "Choice": choice_used,
                        "Voting Power": vp,
                        "VP Ratio (%)": round(vp_ratio * 100, 4),
                        "Is Whale": vp_ratio > 0.05,
                        "Aligned With Majority": aligned,
                        "Vote Timestamp": datetime.utcfromtimestamp(v["created"]).isoformat()
                    })

                append_rows_to_csv(rows)

                completed.add(pid)
                save_progress(space, completed)

                print(f"✅ 写入 {len(rows)} 行 | space 完成 proposals={len(completed)}")
                time.sleep(SLEEP_BETWEEN_CALLS)

            except Exception as e:
                # Proposal-level fail: log and continue
                log_failure("PROPOSAL_FAIL", f"{space} | {pid} | {repr(e)}")
                print(f"❌ Proposal 抓取失败（已记录 failures.log），继续下一个：{e}")
                continue

    print(f"\n🎉 全部完成（或已尽可能完成）！")
    print(f"📁 CSV：{OUT_CSV}")
    print(f"📄 failures：{FAIL_LOG}")
    print(f"📌 progress_dir：{PROGRESS_DIR}")


if __name__ == "__main__":
    main()
# Out:
# ✅ 从 selected_space_ids 读取 spaces 数量：441
# 🔎 正在获取 followersCount 并按重要性排序（None 放最后）...
#    ... followersCount fetched 25/441
#    ... followersCount fetched 50/441
# ⚠️ 请求失败（attempt 1/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 1.0s
# ⚠️ 请求失败（attempt 2/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 2.2s
# ⚠️ 请求失败（attempt 3/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 4.4s
# ⚠️ 请求失败（attempt 4/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 8.6s
#    ... followersCount fetched 75/441
#    ... followersCount fetched 100/441
#    ... followersCount fetched 125/441
#    ... followersCount fetched 150/441
# ⚠️ 请求失败（attempt 1/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 1.0s
# ⚠️ 请求失败（attempt 2/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 2.2s
# ⚠️ 请求失败（attempt 3/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 4.4s
# ⚠️ 请求失败（attempt 4/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 8.6s
# ⚠️ 请求失败（attempt 5/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 16.8s
#    ... followersCount fetched 175/441
#    ... followersCount fetched 200/441
#    ... followersCount fetched 225/441
#    ... followersCount fetched 250/441
# ⚠️ 请求失败（attempt 1/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 1.0s
# ⚠️ 请求失败（attempt 2/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 2.2s
# ⚠️ 请求失败（attempt 3/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 4.4s
# ⚠️ 请求失败（attempt 4/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 8.6s
# ⚠️ 请求失败（attempt 5/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 16.8s
#    ... followersCount fetched 275/441
#    ... followersCount fetched 300/441
#    ... followersCount fetched 325/441
#    ... followersCount fetched 350/441
# ⚠️ 请求失败（attempt 1/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 1.0s
# ⚠️ 请求失败（attempt 2/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 2.2s
# ⚠️ 请求失败（attempt 3/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 4.4s
# ⚠️ 请求失败（attempt 4/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 8.6s
# ⚠️ 请求失败（attempt 5/6）：HTTP 429: {"error":"unauthorized","error_description":"too many requests, refer to https://docs.snapshot.box/tools/api/api-keys#limits"} | backoff 16.8s
#    ... followersCount fetched 375/441
#    ... followersCount fetched 400/441
#    ... followersCount fetched 425/441
# ✅ followers 排序后前 5 个： [('stgdao.eth', 921360), ('arbitrumfoundation.eth', 323351), ('opcollective.eth', 203997), ('aavedao.eth', 157285), ('gitcoindao.eth', 150443)]
#
# ==========================================================================================
# 🏷️  Space [1/441]: stgdao.eth | followersCount=921360
# ==========================================================================================
# 📌 已完成 proposals 数：0（data/processed/votes_441\progress_by_space\progress_stgdao.eth.json）
#
# 🚀 开始抓取 Space=stgdao.eth 的全部 proposals ...
# 📦 stgdao.eth proposals: 1 ~ 100
# 📦 stgdao.eth proposals: 101 ~ 155
# ✅ stgdao.eth proposals 总数：155
#
# 🔍 [stgdao.eth] Proposal 1/155：LayerZero Proposes Acquisition of Stargate (STG)
# 🧾 votes 数：15110
# ✅ 写入 15110 行 | space 完成 proposals=1
#
# 🔍 [stgdao.eth] Proposal 2/155：Migrate Stargate Protocol Contracts to OneSig
# 🧾 votes 数：6489
# ✅ 写入 6489 行 | space 完成 proposals=2
#
# 🔍 [stgdao.eth] Proposal 3/155：Stargate Finance Stablecoin Staking Yield Event
# 🧾 votes 数：4
# ✅ 写入 4 行 | space 完成 proposals=3
#
# 🔍 [stgdao.eth] Proposal 4/155：StargateDAO Capital Allocation to Intent Based Systems
# 🧾 votes 数：6244
# ✅ 写入 6244 行 | space 完成 proposals=4
#
# 🔍 [stgdao.eth] Proposal 5/155：[Ratification] ETH and USDC pools on Cronos zkEVM
# 🧾 votes 数：6496
# ✅ 写入 6496 行 | space 完成 proposals=5
#
# 🔍 [stgdao.eth] Proposal 6/155：[Ratification] Stargate Deployment on Abstract
# 🧾 votes 数：6450
# ✅ 写入 6450 行 | space 完成 proposals=6
#
# 🔍 [stgdao.eth] Proposal 7/155：[Ratification] ETH Pools on Manta Pacific
# 🧾 votes 数：6389
# ✅ 写入 6389 行 | space 完成 proposals=7
#
# 🔍 [stgdao.eth] Proposal 8/155：[Ratification] Final Data RFP Vote - Choice of Artemis Options
# 🧾 votes 数：6343
# ✅ 写入 6343 行 | space 完成 proposals=8
#
# 🔍 [stgdao.eth] Proposal 9/155：[Ratification] Stargate Deployment to Gnosis Chain
# 🧾 votes 数：5862
# ✅ 写入 5862 行 | space 完成 proposals=9
#
# 🔍 [stgdao.eth] Proposal 10/155：[Ratification] ETH Pool on Hemi Network
# 🧾 votes 数：5486
# ✅ 写入 5486 行 | space 完成 proposals=10
#
# 🔍 [stgdao.eth] Proposal 11/155：[Ratification] RFP Request: Comprehensive Data Dashboard
# 🧾 votes 数：5505
# ✅ 写入 5505 行 | space 完成 proposals=11
#
# 🔍 [stgdao.eth] Proposal 12/155：[Ratification] Stargate Deployment to Sonic
# 🧾 votes 数：5655
# ✅ 写入 5655 行 | space 完成 proposals=12
#
# 🔍 [stgdao.eth] Proposal 13/155：[Ratification] Stargate Deployment on Unichain
# 🧾 votes 数：5667
# ✅ 写入 5667 行 | space 完成 proposals=13
#
# 🔍 [stgdao.eth] Proposal 14/155：[Ratification] Integrate with Lightlink Network
# 🧾 votes 数：5627
# ✅ 写入 5627 行 | space 完成 proposals=14
#
# 🔍 [stgdao.eth] Proposal 15/155：[Ratification] Stargate on Soneium
# 🧾 votes 数：5654
# ✅ 写入 5654 行 | space 完成 proposals=15
#
# 🔍 [stgdao.eth] Proposal 16/155：[Ratification] USDC Pool on BNB Chain
# 🧾 votes 数：5678
# ✅ 写入 5678 行 | space 完成 proposals=16
#
# 🔍 [stgdao.eth] Proposal 17/155：Predicate DVN added to Stargate’s DVN set
# 🧾 votes 数：6005
# ✅ 写入 6005 行 | space 完成 proposals=17
#
# 🔍 [stgdao.eth] Proposal 18/155：ETH and USDC Pools on Sophon
# 🧾 votes 数：8780
# ✅ 写入 8780 行 | space 完成 proposals=18
#
# 🔍 [stgdao.eth] Proposal 19/155：Launch of EURC pools on Stargate
# 🧾 votes 数：7664
# ✅ 写入 7664 行 | space 完成 proposals=19
#
# 🔍 [stgdao.eth] Proposal 20/155：Building Stargate’s Flagship Cross-Chain Retail Superapp – A Glue x Stargate Par
# 🧾 votes 数：9077
# ✅ 写入 9077 行 | space 完成 proposals=20
#
# 🔍 [stgdao.eth] Proposal 21/155：Stargate Integration with Espresso Network
# 🧾 votes 数：22887
# ✅ 写入 22887 行 | space 完成 proposals=21
#
# 🔍 [stgdao.eth] Proposal 22/155：Balanced earnings distribution: Increasing Value Accrual for STG Stakers
# 🧾 votes 数：13327
# ✅ 写入 13327 行 | space 完成 proposals=22
#
# 🔍 [stgdao.eth] Proposal 23/155：Fee Distribution Revamp
# 🧾 votes 数：9704
# ✅ 写入 9704 行 | space 完成 proposals=23
#
# 🔍 [stgdao.eth] Proposal 24/155：Deploy WETH/wstETH LP liquidity on Jellyverse on Sei
# 🧾 votes 数：8415
# ✅ 写入 8415 行 | space 完成 proposals=24
#
# 🔍 [stgdao.eth] Proposal 25/155：Stargate Integration Proposal: Swell L2 ETH Pool Deployment
# 🧾 votes 数：8494
# ✅ 写入 8494 行 | space 完成 proposals=25
#
# 🔍 [stgdao.eth] Proposal 26/155：Deploy STG liquidity on Kodiak Finance on Berachain mainnet & Make Kodiak the ST
# 🧾 votes 数：8433
# ✅ 写入 8433 行 | space 完成 proposals=26
#
# 🔍 [stgdao.eth] Proposal 27/155：ETH and USDC pools on Cronos zkEVM
# 🧾 votes 数：10793
# ✅ 写入 10793 行 | space 完成 proposals=27
#
# 🔍 [stgdao.eth] Proposal 28/155：[Fast Track] Deploy USDC.e/HONEY Liquidity on BeraSwap
# 🧾 votes 数：6878
# ✅ 写入 6878 行 | space 完成 proposals=28
#
# 🔍 [stgdao.eth] Proposal 29/155：StargateDAO Treasury Consolidation Proposal
# 🧾 votes 数：6747
# ✅ 写入 6747 行 | space 完成 proposals=29
#
# 🔍 [stgdao.eth] Proposal 30/155：[Fast Track] HEP-1: Hydra Expansion Program
# 🧾 votes 数：3384
# ✅ 写入 3384 行 | space 完成 proposals=30
#
# 🔍 [stgdao.eth] Proposal 31/155：Stargate Deployment on Abstract
# 🧾 votes 数：14554
# ✅ 写入 14554 行 | space 完成 proposals=31
#
# 🔍 [stgdao.eth] Proposal 32/155：Stargate Deployment on Hedera
# 🧾 votes 数：13735
# ✅ 写入 13735 行 | space 完成 proposals=32
#
# 🔍 [stgdao.eth] Proposal 33/155：ETH Pool on Manta Pacific
# 🧾 votes 数：11927
# ✅ 写入 11927 行 | space 完成 proposals=33
#
# 🔍 [stgdao.eth] Proposal 34/155：Stargate Deployment on Conflux
# 🧾 votes 数：10614
# ✅ 写入 10614 行 | space 完成 proposals=34
#
# 🔍 [stgdao.eth] Proposal 35/155：Final Data RFP Vote - Choice of Artemis Options
# 🧾 votes 数：10735
# ✅ 写入 10735 行 | space 完成 proposals=35
#
# 🔍 [stgdao.eth] Proposal 36/155：Stargate Deployment to Gnosis Chain
# 🧾 votes 数：15493
# ✅ 写入 15493 行 | space 完成 proposals=36
#
# 🔍 [stgdao.eth] Proposal 37/155：Absolutely thrilling news for all Stargate users!
# 🧾 votes 数：10
# ✅ 写入 10 行 | space 完成 proposals=37
#
# 🔍 [stgdao.eth] Proposal 38/155：Absolutely thrilling news for all Stargate users!
# 🧾 votes 数：17
# ✅ 写入 17 行 | space 完成 proposals=38
#
# 🔍 [stgdao.eth] Proposal 39/155：Absolutely thrilling news for all Stargate users!
# 🧾 votes 数：17
# ✅ 写入 17 行 | space 完成 proposals=39
#
# 🔍 [stgdao.eth] Proposal 40/155：Absolutely thrilling news for all Stargate users!
# 🧾 votes 数：15
# ✅ 写入 15 行 | space 完成 proposals=40
#
# 🔍 [stgdao.eth] Proposal 41/155：After a Successful DAO Vote, Stargate decided to Launch the 1 Phase of the $gSTG
# 🧾 votes 数：26
# ✅ 写入 26 行 | space 完成 proposals=41
#
# 🔍 [stgdao.eth] Proposal 42/155：ETH Pool on the Hemi Network
# 🧾 votes 数：14743
# ✅ 写入 14743 行 | space 完成 proposals=42
#
# 🔍 [stgdao.eth] Proposal 43/155：Stargate Foundation Budget (Nov 2024 - October 2025)
# 🧾 votes 数：11072
# ✅ 写入 11072 行 | space 完成 proposals=43
#
# 🔍 [stgdao.eth] Proposal 44/155：RFP Request: Comprehensive Data Dashboard
# 🧾 votes 数：16937
# ✅ 写入 16937 行 | space 完成 proposals=44
#
# 🔍 [stgdao.eth] Proposal 45/155：ETH Pool on Mode
# 🧾 votes 数：16992
# ✅ 写入 16992 行 | space 完成 proposals=45
#
# 🔍 [stgdao.eth] Proposal 46/155：Stargate Deployment to Sonic
# 🧾 votes 数：16642
# ✅ 写入 16642 行 | space 完成 proposals=46
#
# 🔍 [stgdao.eth] Proposal 47/155：Stargate Deployment to Unichain
# 🧾 votes 数：8952
# ✅ 写入 8952 行 | space 完成 proposals=47
#
# 🔍 [stgdao.eth] Proposal 48/155：Integrate with LightLink Network
# 🧾 votes 数：14542
# ✅ 写入 14542 行 | space 完成 proposals=48
#
# 🔍 [stgdao.eth] Proposal 49/155：Stargate Interest ($iSTG) Rewards Distribution allocation increase from 1% to 2%
# 🧾 votes 数：12
# ✅ 写入 12 行 | space 完成 proposals=49
#
# 🔍 [stgdao.eth] Proposal 50/155：Stargate Interest ($iSTG) Rewards Distribution allocation increase from 1% to 2%
# 🧾 votes 数：11
# ✅ 写入 11 行 | space 完成 proposals=50
#
# 🔍 [stgdao.eth] Proposal 51/155：Stargate Interest ($iSTG) Rewards Distribution allocation increase from 1% to 2%
# 🧾 votes 数：11
# ✅ 写入 11 行 | space 完成 proposals=51
#
# 🔍 [stgdao.eth] Proposal 52/155：Stargate Interest ($iSTG) Rewards Distribution allocation increase from 1% to 2%
# 🧾 votes 数：12
# ✅ 写入 12 行 | space 完成 proposals=52
#
# 🔍 [stgdao.eth] Proposal 53/155：Stargate Interest ($iSTG) Rewards Distribution allocation increase from 1% to 2%
# 🧾 votes 数：14
# ✅ 写入 14 行 | space 完成 proposals=53
#
# 🔍 [stgdao.eth] Proposal 54/155：Stargate on Soneium
# 🧾 votes 数：4533
# ✅ 写入 4533 行 | space 完成 proposals=54
#
# 🔍 [stgdao.eth] Proposal 55/155：USDC Pool on BNB Chain
# 🧾 votes 数：5614
# ✅ 写入 5614 行 | space 完成 proposals=55
#
# 🔍 [stgdao.eth] Proposal 56/155：Integrate with Sei Network
# 🧾 votes 数：5800
# ✅ 写入 5800 行 | space 完成 proposals=56
#
# 🔍 [stgdao.eth] Proposal 57/155：StargateDAO Governance Process
# 🧾 votes 数：5746
# ✅ 写入 5746 行 | space 完成 proposals=57
#
# 🔍 [stgdao.eth] Proposal 58/155：Enable wBTC on KAVA Chain
# 🧾 votes 数：37170
# ✅ 写入 37170 行 | space 完成 proposals=58
#
# 🔍 [stgdao.eth] Proposal 59/155：Proposal: Launch of Stargate v2 on Core Chain
# 🧾 votes 数：41387
# ✅ 写入 41387 行 | space 完成 proposals=59
#
# 🔍 [stgdao.eth] Proposal 60/155：Stargate Foundation's Amendment to RFP Proposal
# 🧾 votes 数：66729
# ✅ 写入 66729 行 | space 完成 proposals=60
#
# 🔍 [stgdao.eth] Proposal 61/155：Stargate Foundation RFP Proposal
# 🧾 votes 数：215698
# ✅ 写入 215698 行 | space 完成 proposals=61
#
# 🔍 [stgdao.eth] Proposal 62/155：Distribution of RFP
# 🧾 votes 数：207248
# ✅ 写入 207248 行 | space 完成 proposals=62
#
# 🔍 [stgdao.eth] Proposal 63/155：Stargate ImmuneFi Bug Bounty Program
# 🧾 votes 数：85269
# ✅ 写入 85269 行 | space 完成 proposals=63
#
# 🔍 [stgdao.eth] Proposal 64/155：Proposal to wind down support for the Fantom Ecosystem
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
# ⚠️ 请求失败（attempt 1/6）：HTTPSConnectionPool(host='hub.snapshot.org', port=443): Read timed out. (read timeout=30) | backoff 1.0s
